# %% [markdown]
# # 使用 Stable baselines 在 Amazon SageMaker 上进行强化学习训练

# %% [markdown]
# ## 概要介绍

# %% [markdown]
# <img src="https://stable-baselines.readthedocs.io/en/master/_static/logo.png" width="300">
#
# [OpenAI Gym](https://gym.openai.com) 是一个开源的强化学习工具包,它提供了标准的接口和一组环境, 通过这些环境我们可以快速的进行强化学习实验.
#
# [Stable baselines](https://stable-baselines.readthedocs.io/en/master/) 是在OpenAI Baselines 基础算法上进行增强的开源强化学习算法项目.
#
# 本次实验我们将使用stable baselines 自带的算法进行对OpenAI Gym自带的雅达利游戏 '吃豆人' [**MsPacman-v0**](https://gym.openai.com/envs/MsPacman-v0/) 进行训练.

# %% [markdown]
# ## 强化学习机制

# %% [markdown]
# 强化学习（英语：Reinforcement learning，简称RL）是机器学习中的一个领域，强调如何基于环境而行动，以取得最大化的预期利益。强化学习是除了监督学习和非监督学习之外的第三种基本的机器学习方法。与监督学习不同的是，强化学习不需要带标签的输入输出对，同时也无需对非最优解的精确地纠正。其关注点在于寻找探索（对未知领域的）和利用（对已有知识的）的平衡，强化学习中的“探索-利用”的交换。
# [维基百科]
#
# <img src="src/rl.png">

# %% [markdown]
# Amazon SageMaker
#
# SageMaker是亚马逊云计算（Amazon Web Service）推出的一个端到端机器学习平台产品，它为数据科学家或算法工程师提供了拿来即用的计算资源和所需的机器学习/深度学习执行环境，您可以直接使用它集成的内置算法或提交自己的代码快速拉起计算资源来完成相应机器学习模型的迭代和部署推理。
#
# <img src="src/sm-arch.png">

# %%
rl_problem = 'pacman'

# %% [markdown]
# ## 前置条件
#
# ### 导入
#
# 导入我们需要的Python库, 以及需要的辅助方法: get_execution_role, wait_for_s3_object.

# %%
import sagemaker
import boto3
import sys
import os
import subprocess
from IPython.display import HTML
import time
from time import gmtime, strftime
sys.path.append("common")
from misc import wait_for_s3_object
from docker_utils import build_and_push_docker_image
from sagemaker.rl import RLEstimator

# %% [markdown]
# ### 设置 S3 桶
#
# 通过Sagemaker SDK获取默认s3桶, 该桶将会存储模型,检查点和其他元数据

# %%
sage_session = sagemaker.session.Session()
s3_bucket = sage_session.default_bucket()  
s3_output_path = 's3://{}/'.format(s3_bucket)
print("S3 bucket path: {}".format(s3_output_path))
# Out:
# S3 bucket path: s3://sagemaker-us-east-1-596030579944/

# %% [markdown]
# ### 定义任务/Image 名称变量
#
# 我们定义为训练任务和image定义前缀变量: job_name_prefix*

# %%
# create a descriptive job name 
job_name_prefix = 'rl-stabebaselines-'+rl_problem

# %% [markdown]
# ### 获取IAM角色
#
# 使用SageMaker SDK 的`get_execution_role()` 获取SageMaker Notebook的Role, `role = sagemaker.get_execution_role()`

# %%
role = sagemaker.get_execution_role()
print("Using IAM role arn: {}".format(role))
# Out:
# Using IAM role arn: arn:aws:iam::596030579944:role/service-role/AmazonSageMaker-ExecutionRole-20191130T110013

# %% [markdown]
# ## 构建 docker 镜像
#
# 我们必须要构建自己的docker 镜像.  This takes care of everything:
#
# 1. 拉取基础镜像
# 2. 安装g++,cmake 等编译工具
# 3. 安装stable-baselines 和它需要的依赖库, etc OpenMPI
# 3. 将镜像上传到Amazone ECR
#
# 这个步骤通常会花费 3-10分钟,具体时间取决于你的网络速度和notebook实例类型.

# %%
# %%time
instance_type = 'ml.c5.xlarge'
cpu_or_gpu = 'gpu' if instance_type.startswith('ml.p') or instance_type.startswith('ml.g') else 'cpu'
repository_short_name = "sagemaker-roboschool-stablebaselines-%s" % cpu_or_gpu
docker_build_args = { 
    'AWS_REGION': boto3.Session().region_name,
}
custom_image_name = build_and_push_docker_image(repository_short_name, build_args=docker_build_args)
print("Using ECR image %s" % custom_image_name)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Logged into ECR
# Building docker image sagemaker-roboschool-stablebaselines-cpu from Dockerfile
# $ docker build -t sagemaker-roboschool-stablebaselines-cpu -f Dockerfile . --build-arg AWS_REGION=us-east-1
# Sending build context to Docker daemon  6.705MB
# Step 1/42 : ARG AWS_REGION
# Step 2/42 : FROM 520713654638.dkr.ecr.${AWS_REGION}.amazonaws.com/sagemaker-rl-tensorflow:coach0.11.0-cpu-py3
#  ---> 69468aab742c
# Step 3/42 : RUN apt update
#  ---> Using cache
#  ---> 4cf9b74cd577
# Step 4/42 : RUN apt-get install -y gcc-4.9 cmake
#  ---> Using cache
#  ---> 2716600c4320
# Step 5/42 : RUN update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-4.9 50
#  ---> Using cache
#  ---> 2bfb0d395cde
# Step 6/42 : RUN apt-get install -y g++-4.9
#  ---> Using cache
#  ---> bfbf58e44a1f
# Step 7/42 : RUN update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-4.9 50
#  ---> Using cache
#  ---> 11080e07c4da
# Step 8/42 : RUN buildDeps="         wget         build-essential     "     && apt-get update && apt-get install -y --no-install-recommends $buildDeps     && apt-get clean     && rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> 12f80a4854b5
# Step 9/42 : RUN mkdir /tmp/openmpi &&     cd /tmp/openmpi &&     wget https://www.open-mpi.org/software/ompi/v3.0/downloads/openmpi-3.0.0.tar.gz &&     tar zxf openmpi-3.0.0.tar.gz &&     cd openmpi-3.0.0 &&     ./configure --enable-orterun-prefix-by-default &&     make -j $(nproc) all &&     make install &&     ldconfig &&     rm -rf /tmp/openmpi
#  ---> Using cache
#  ---> e0e851f9dde4
# Step 10/42 : RUN pip install --upgrade pip && pip install tensorflow==1.15.0
#  ---> Using cache
#  ---> f3623bd63ff5
# Step 11/42 : RUN ldconfig /usr/local/cuda-9.0/targets/x86_64-linux/lib/stubs &&     HOROVOD_CPU_ALLREDUCE=MPI HOROVOD_WITH_TENSORFLOW=1 HOROVOD_WITHOUT_GLOO=1 pip install --no-cache-dir horovod &&     ldconfig
#  ---> Using cache
#  ---> 407dec2dc911
# Step 12/42 : RUN mv /usr/local/bin/mpirun /usr/local/bin/mpirun.real &&     echo '#!/bin/bash' > /usr/local/bin/mpirun &&     echo 'mpirun.real --allow-run-as-root "$@"' >> /usr/local/bin/mpirun &&     chmod a+x /usr/local/bin/mpirun
#  ---> Using cache
#  ---> a5570392fa8c
# Step 13/42 : RUN echo "hwloc_base_binding_policy = none" >> /usr/local/etc/openmpi-mca-params.conf &&     echo "rmaps_base_mapping_policy = slot" >> /usr/local/etc/openmpi-mca-params.conf
#  ---> Using cache
#  ---> d4842c053582
# Step 14/42 : RUN pip install mpi4py
#  ---> Using cache
#  ---> 8dccbcf8e077
# Step 15/42 : ENV LD_LIBRARY_PATH=/usr/local/openmpi/lib:$LD_LIBRARY_PATH
#  ---> Using cache
#  ---> 8a6576b6315e
# Step 16/42 : ENV PATH /usr/local/openmpi/bin/:$PATH
#  ---> Using cache
#  ---> 875b15a125ad
# Step 17/42 : ENV PATH=/usr/local/nvidia/bin:$PATH
#  ---> Using cache
#  ---> 3e54b2596c6f
# Step 18/42 : ENV PYTHONDONTWRITEBYTECODE=1 PYTHONUNBUFFERED=1
#  ---> Using cache
#  ---> bdcfe4d4dd0e
# Step 19/42 : RUN apt-get update && apt-get install -y --no-install-recommends openssh-server &&     mkdir -p /var/run/sshd
#  ---> Using cache
#  ---> df81d30c47ba
# Step 20/42 : RUN sed 's@session\s*required\s*pam_loginuid.so@session optional pam_loginuid.so@g' -i /etc/pam.d/sshd
#  ---> Using cache
#  ---> 1ef1659e647e
# Step 21/42 : RUN mkdir -p /root/.ssh/ &&   ssh-keygen -q -t rsa -N '' -f /root/.ssh/id_rsa &&   cp /root/.ssh/id_rsa.pub /root/.ssh/authorized_keys &&   printf "Host *\n  StrictHostKeyChecking no\n" >> /root/.ssh/config
#  ---> Using cache
#  ---> 9d843a085a77
# Step 22/42 : COPY resources/changehostname.c /
#  ---> Using cache
#  ---> 0a1aaf6888dc
# Step 23/42 : COPY resources/change-hostname.sh /
#  ---> Using cache
#  ---> b83d41475e7c
# Step 24/42 : COPY resources/change-hostname.sh /usr/local/bin/change-hostname.sh
#  ---> Using cache
#  ---> 5dba03d67296
# Step 25/42 : RUN chmod +x /usr/local/bin/change-hostname.sh
#  ---> Using cache
#  ---> 6cac1d8b7687
# Step 26/42 : RUN chmod +x /change-hostname.sh
#  ---> Using cache
#  ---> 1065435f8916
# Step 27/42 : RUN pip install keras
#  ---> Using cache
#  ---> ba7eb199b501
# Step 28/42 : RUN pip install retrying
#  ---> Using cache
#  ---> d90471be3977
# Step 29/42 : WORKDIR /opt
#  ---> Using cache
#  ---> c05f185cc5d3
# Step 30/42 : RUN apt-get update && apt-get install -y       git cmake ffmpeg pkg-config       qtbase5-dev libqt5opengl5-dev libassimp-dev       libtinyxml-dev       libgl1-mesa-dev     && cd /opt     && apt-get clean && rm -rf /var/cache/apt/archives/* /var/lib/apt/lists/*
#  ---> Using cache
#  ---> 09c7588a6530
# Step 31/42 : RUN apt-get update &&     apt-get install -y libboost-python-dev
#  ---> Using cache
#  ---> 60809805cd69
# Step 32/42 : RUN apt-get update     && apt-get install -y --no-install-recommends python3.6-dev     && ln -s -f /usr/bin/python3.6 /usr/bin/python     && apt-get clean     && rm -rf /var/cache/apt/archives/* /var/lib/apt/lists/*
#  ---> Using cache
#  ---> cd81fe72ee4a
# Step 33/42 : RUN curl -fSsL -O https://bootstrap.pypa.io/get-pip.py &&     python get-pip.py &&     rm get-pip.py
#  ---> Using cache
#  ---> b929a8b4c2af
# Step 34/42 : RUN pip install --upgrade     pip     setuptools
#  ---> Using cache
#  ---> c07d43712602
# Step 35/42 : RUN pip install roboschool==1.0.48
#  ---> Using cache
#  ---> a3fea08eedc5
# Step 36/42 : ENV PYTHONUNBUFFERED 1
#  ---> Using cache
#  ---> 0fdbb3d5c0f0
# Step 37/42 : RUN apt-get update && apt-get install -y cmake libopenmpi-dev python3-dev zlib1g-dev wget
#  ---> Using cache
#  ---> dd8525e57611
# Step 38/42 : ENV BASELINES_PATH /opt/baselines/
#  ---> Using cache
#  ---> ddc9167397d7
# Step 39/42 : RUN git clone https://github.com/openai/baselines.git
#  ---> Using cache
#  ---> 38ca5900ab71
# Step 40/42 : RUN pip install -e ${BASELINES_PATH}
#  ---> Using cache
#  ---> accf4114963b
# Step 41/42 : RUN pip install stable-baselines
#  ---> Using cache
#  ---> 238f0113aa19
# Step 42/42 : RUN python -c "import gym; import roboschool;"
#  ---> Using cache
#  ---> 78d76e814253
# Successfully built 78d76e814253
# Successfully tagged sagemaker-roboschool-stablebaselines-cpu:latest
# Done building docker image sagemaker-roboschool-stablebaselines-cpu
# ECR repository already exists: sagemaker-roboschool-stablebaselines-cpu
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# Logged into ECR
# $ docker tag sagemaker-roboschool-stablebaselines-cpu 596030579944.dkr.ecr.us-east-1.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu
# Pushing docker image to ECR repository 596030579944.dkr.ecr.us-east-1.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu
#
# $ docker push 596030579944.dkr.ecr.us-east-1.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu
# The push refers to repository [596030579944.dkr.ecr.us-east-1.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu]
# b1396edc97d9: Preparing
# 56f3e77d14d9: Preparing
# 7db5b3923c17: Preparing
# ebe1b139b821: Preparing
# 7cda8c95dc01: Preparing
# e1817f2f0ac1: Preparing
# f2007015664c: Preparing
# 75ecbb28e85b: Preparing
# ec61539038b8: Preparing
# 5e6b908340f8: Preparing
# 29b9c9438c81: Preparing
# 9f518d9a66c5: Preparing
# 329fa57e07d6: Preparing
# e36ed9c541df: Preparing
# 065496489196: Preparing
# e4c1ca7f5536: Preparing
# d734703721f5: Preparing
# d328a096acf4: Preparing
# fc2c74926f20: Preparing
# 5c8acab9ef7f: Preparing
# d850e6c80ab9: Preparing
# fce1a619e2d1: Preparing
# 430ef47e726f: Preparing
# 3ec4a0a4e743: Preparing
# d7da097849c9: Preparing
# 96e3625223ae: Preparing
# f71e51e8ec83: Preparing
# b44dd35a8494: Preparing
# e3aaf0464edc: Preparing
# 59d4fa228f3a: Preparing
# 0614b29347cf: Preparing
# 926c7d6c0164: Preparing
# d6df154a329b: Preparing
# a0f6963b385e: Preparing
# 1f54e44d071b: Preparing
# 60a4c6264060: Preparing
# 6ee8fe30b55b: Preparing
# 36cb14e2633d: Preparing
# c9bbcdfaaa98: Preparing
# 09b011f6bf18: Preparing
# 296294040c48: Preparing
# 302af95b9e68: Preparing
# 0ecacb4d5bb1: Preparing
# d6db7d05e3b2: Preparing
# 8d999119430c: Preparing
# fe4ed9a0e78a: Preparing
# 3db5746c911a: Preparing
# 819a824caf70: Preparing
# 647265b9d8bc: Preparing
# 41c002c8a6fd: Preparing
# e1817f2f0ac1: Waiting
# f2007015664c: Waiting
# 75ecbb28e85b: Waiting
# ec61539038b8: Waiting
# 5e6b908340f8: Waiting
# 29b9c9438c81: Waiting
# 9f518d9a66c5: Waiting
# 329fa57e07d6: Waiting
# e36ed9c541df: Waiting
# 065496489196: Waiting
# e4c1ca7f5536: Waiting
# d734703721f5: Waiting
# d328a096acf4: Waiting
# fc2c74926f20: Waiting
# 5c8acab9ef7f: Waiting
# d850e6c80ab9: Waiting
# fce1a619e2d1: Waiting
# 430ef47e726f: Waiting
# 3ec4a0a4e743: Waiting
# d7da097849c9: Waiting
# 96e3625223ae: Waiting
# f71e51e8ec83: Waiting
# b44dd35a8494: Waiting
# e3aaf0464edc: Waiting
# 59d4fa228f3a: Waiting
# 0614b29347cf: Waiting
# 926c7d6c0164: Waiting
# d6df154a329b: Waiting
# a0f6963b385e: Waiting
# 1f54e44d071b: Waiting
# 60a4c6264060: Waiting
# 6ee8fe30b55b: Waiting
# 36cb14e2633d: Waiting
# c9bbcdfaaa98: Waiting
# 09b011f6bf18: Waiting
# 296294040c48: Waiting
# 302af95b9e68: Waiting
# 0ecacb4d5bb1: Waiting
# d6db7d05e3b2: Waiting
# 8d999119430c: Waiting
# fe4ed9a0e78a: Waiting
# 3db5746c911a: Waiting
# 819a824caf70: Waiting
# 647265b9d8bc: Waiting
# 41c002c8a6fd: Waiting
# 7db5b3923c17: Layer already exists
# ebe1b139b821: Layer already exists
# 7cda8c95dc01: Layer already exists
# b1396edc97d9: Layer already exists
# 56f3e77d14d9: Layer already exists
# e1817f2f0ac1: Layer already exists
# f2007015664c: Layer already exists
# 75ecbb28e85b: Layer already exists
# ec61539038b8: Layer already exists
# 5e6b908340f8: Layer already exists
# 29b9c9438c81: Layer already exists
# 9f518d9a66c5: Layer already exists
# 329fa57e07d6: Layer already exists
# e36ed9c541df: Layer already exists
# 065496489196: Layer already exists
# e4c1ca7f5536: Layer already exists
# d734703721f5: Layer already exists
# d328a096acf4: Layer already exists
# 5c8acab9ef7f: Layer already exists
# fc2c74926f20: Layer already exists
# d850e6c80ab9: Layer already exists
# fce1a619e2d1: Layer already exists
# 430ef47e726f: Layer already exists
# 3ec4a0a4e743: Layer already exists
# d7da097849c9: Layer already exists
# f71e51e8ec83: Layer already exists
# b44dd35a8494: Layer already exists
# 96e3625223ae: Layer already exists
# 59d4fa228f3a: Layer already exists
# 0614b29347cf: Layer already exists
# 926c7d6c0164: Layer already exists
# a0f6963b385e: Layer already exists
# d6df154a329b: Layer already exists
# 1f54e44d071b: Layer already exists
# 60a4c6264060: Layer already exists
# 6ee8fe30b55b: Layer already exists
# 36cb14e2633d: Layer already exists
# c9bbcdfaaa98: Layer already exists
# 09b011f6bf18: Layer already exists
# 296294040c48: Layer already exists
# 302af95b9e68: Layer already exists
# 0ecacb4d5bb1: Layer already exists
# d6db7d05e3b2: Layer already exists
# 8d999119430c: Layer already exists
# fe4ed9a0e78a: Layer already exists
# 3db5746c911a: Layer already exists
# 819a824caf70: Layer already exists
# 647265b9d8bc: Layer already exists
# 41c002c8a6fd: Layer already exists
# e3aaf0464edc: Layer already exists
# latest: digest: sha256:9335e89b53c7ec51b8bb900bb72e23cee1b8e59f0a1a9c366be1ece7b7f92fe7 size: 10817
# Done pushing 596030579944.dkr.ecr.us-east-1.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu
# Using ECR image 596030579944.dkr.ecr.us-east-1.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu
# CPU times: user 134 ms, sys: 42.2 ms, total: 176 ms
# Wall time: 3.32 s

# %% [markdown]
# ## 使用预构建 docker 镜像(可选)
#
# 为了节省实验时间,我们在AWS公开镜像仓库预先构建好了需要的镜像,你们仅需要推送到自己的ECR仓库即可.
#
# 1. 拉取prebuild镜像
# 2. 推送到ECR
# 3. 设置custom_image_name变量

# %%
#拉取&推送到ECR
# !sh ./use_public_prebuild.sh

# %%
#设置Image的名字
aws_account = boto3.Session().client("sts").get_caller_identity()['Account']
aws_region =  boto3.Session().region_name
custom_image_name = f'{aws_account}.dkr.ecr.{aws_region}.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu'

# %% [markdown]
# ## 编写训练代码

# %% [markdown]
# #### 配置 RL 算法超参数
#
# 配置RL训练作业的预设文件是在./src目录中的preset-pacman.py中定义的。使用预设文件，您可以定义代理参数以选择特定的代理算法。您还可以设置环境参数，定义计划和可视化参数以及定义图形管理器。预设包含以下PPO1训练的需要超参数：
#
# * `num_timesteps`: (int) Number of training steps - Preset: 1e4
# * `timesteps_per_actorbatch` – (int) timesteps per actor per update - Preset: 2048
# * `clip_param` – (float) clipping parameter epsilon - Preset: 0.2
# * `entcoeff` – (float) the entropy loss weight - Preset: 0.0
# * `optim_epochs` – (float) the optimizer’s number of epochs - Preset: 10
# * `optim_stepsize` – (float) the optimizer’s stepsize - Preset: 3e-4
# * `optim_batchsize` – (int) the optimizer’s the batch size - Preset: 64
# * `gamma` – (float) discount factor - Preset: 0.99
# * `lam` – (float) advantage estimation - Preset: 0.95
# * `schedule` – (str) The type of scheduler for the learning rate update (‘linear’, ‘constant’, ‘double_linear_con’, ‘middle_drop’ or ‘double_middle_drop’) - Preset: linear
# * `verbose` – (int) the verbosity level: 0 none, 1 training information, 2 tensorflow debug - Preset: 1
#
# 你可以在这里获取到完整的PPO1算法超参数列表和详细文档: https://stable-baselines.readthedocs.io/en/master/modules/ppo1.html
#
#
# 通过指定RLSTABLEBASELINES_PRESET超参数，可以制定预设超参数定义文件,这里我们使用了`"RLSTABLEBASELINES_PRESET":"preset-{}.py".format(rl_problem)`

# %% [markdown]
# ####  查看preset-pacman.py 超参数定义文件

# %%
# !pygmentize src/preset-{rl_problem}.py
# Out:
# import argparse
#
# from sagemaker_rl.stable_baselines_launcher import SagemakerStableBaselinesPPO1Launcher, create_env
#
#
# def parse_args():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--output_path', default="/opt/ml/output/intermediate/", type=str)
#     parser.add_argument('--num_timesteps', default=1e4) #default 1e4
#     parser.add_argument('--timesteps_per_actorbatch', default=2048, type=int)
#     parser.add_argument('--clip_param', default=0.2, type=float)
#     parser.add_argument('--entcoeff', default=0.0, type=float)
#     parser.add_argument('--optim_epochs', default=10, type=int)
#     parser.add_argument('--optim_stepsize', default=3e-4)
#     parser.add_argument('--optim_batchsize', default=64, type=int)
#     parser.add_argument('--gamma', default=0.99, type=float)
#     parser.add_argument('--lam', default=0.95, type=float)
#     parser.add_argument('--schedule', default="linear", type=str)
#     parser.add_argument('--verbose', default=1, type=int)
#
#     return parser.parse_known_args()
#
#
# def main():
#     args, unknown = parse_args()
#
#     print("Launching training script with stable baselines PPO1")
#     SagemakerStableBaselinesPPO1Launcher(
#         #env=create_env(env_id="CartPole-v1", output_path=args.output_path),
#         #env=create_env(env_id="SpaceInvaders-v0", output_path=args.output_path),
#         env=create_env(env_id="MsPacman-v0", output_path=args.output_path),
#
#
#         output_path=args.output_path,
#         timesteps_per_actorbatch=int(args.timesteps_per_actorbatch),
#         clip_param=float(args.clip_param),
#         entcoeff=float(args.entcoeff),
#         optim_epochs=int(args.optim_epochs),
#         optim_stepsize=float(args.optim_stepsize),
#         optim_batchsize=int(args.optim_batchsize),
#         gamma=args.gamma,
#         lam=float(args.lam),
#         schedule=args.schedule,
#         verbose=int(args.verbose),
#         num_timesteps=float(args.num_timesteps)).run()
#
#
# if __name__ == "__main__":
#     print("Starting training for half cheetah with PPO1")
#     main()

# %% [markdown]
# #### 编写训练代码
#
# 训练代码在`./src`目录中的`train_stable_baselines.py` 文件.

# %%
# !pygmentize src/train_stable_baselines.py
# Out:
# import argparse
#
# from sagemaker_rl.mpi_launcher import MPILauncher
#
#
# def parse_args():
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--RLSTABLEBASELINES_PRESET', required=True, type=str)
#     parser.add_argument('--output_path', default="/opt/ml/output/intermediate/", type=str)
#     parser.add_argument('--instance_type', type=str)
#
#     return parser.parse_known_args()
#
#
# if __name__ == "__main__":
#     args, unknown_args = parse_args()
#     print("Launching train script with MPI: {} and arguments: {}".format(args.RLSTABLEBASELINES_PRESET,
#                                                                          str(unknown_args)))
#     MPILauncher(train_script=args.RLSTABLEBASELINES_PRESET, train_script_args=unknown_args,
#                 instance_type=args.instance_type).mpi_run()

# %% [markdown]
# ## 使用SageMaker SDK 创建 RL 训练任务
#
# 你可以选择 GPU 或者 CPU 来创建SageMaker 训练任务. SageMaker SDK提供了`RLEstimator类`用来创建RL训练任务.
#
# 1. Specify the source directory where the environment, presets and training code is uploaded.
# 2. Specify the entry point as the training code
# 3. Specify the choice of RL toolkit and framework. This automatically resolves to the ECR path for the RL Container.
# 4. Define the training parameters such as the instance count, job name, S3 path for output and job name.
# 5. Specify the hyperparameters for the RL agent algorithm. The `RLSTABLEBASELINES_PRESET` can be used to specify the RL agent algorithm you want to use.
# 6. Define the metrics definitions that you are interested in capturing in your logs. These can also be visualized in CloudWatch and SageMaker Notebooks.
#
# 请注意,所有`preset-pacman.py`文件里的预设超参数都可以通过 `hyperparameters` 进行覆盖.
#
# **Note**: PPO1算法需要使用到MPI, 本次实验中请将实例数量 `instance_count` 设置为 `1`.

# %%
custom_image_name
# Out:
# '907488872981.dkr.ecr.us-west-2.amazonaws.com/sagemaker-roboschool-stablebaselines-cpu'

# %%
# %%time

estimator = RLEstimator(entry_point="train_stable_baselines.py",
                        source_dir='src',
                        dependencies=["common/sagemaker_rl"],
                        image_uri=custom_image_name,
                        role=role,
                        instance_type=instance_type,
                        use_spot_instances=True,
                        max_wait = (72 * 60 * 60),
                        instance_count=2,
                        output_path=s3_output_path,
                        base_job_name=job_name_prefix,
                        hyperparameters={
                            "RLSTABLEBASELINES_PRESET":"preset-{}.py".format(rl_problem),
                            "num_timesteps":1e4,
                            "instance_type":instance_type
                        },
                        metric_definitions= [
                            {
                                "Name":"EpisodesLengthMean",
                                "Regex":"\[.*,.*\]\<stdout\>\:\| *EpLenMean *\| *([-+]?[0-9]*\.?[0-9]*) *\|"
                            },
                            {
                                "Name":"EpisodesRewardMean",
                                "Regex":"\[.*,.*\]\<stdout\>\:\| *EpRewMean *\| *([-+]?[0-9]*\.?[0-9]*) *\|"
                            },
                            {
                                "Name":"EpisodesSoFar",
                                "Regex":"\[.*,.*\]\<stdout\>\:\| *EpisodesSoFar *\| *([-+]?[0-9]*\.?[0-9]*) *\|"
                            }
                        ]
                    )

estimator.fit(wait=True)
# Out:
# 2021-05-18 00:36:35 Starting - Starting the training job...
# 2021-05-18 00:37:04 Starting - Launching requested ML instancesProfilerReport-1621298194: InProgress
# .........
# 2021-05-18 00:38:24 Starting - Preparing the instances for training......
# 2021-05-18 00:39:24 Downloading - Downloading input data
# 2021-05-18 00:39:24 Training - Downloading the training image.........
# 2021-05-18 00:41:05 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-05-18 00:41:01,783 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-05-18 00:41:01,787 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-18 00:41:02,142 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-18 00:41:02,151 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_estimator": "RLEstimator"
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "num_timesteps": 10000.0,
#         "RLSTABLEBASELINES_PRESET": "preset-pacman.py",
#         "instance_type": "ml.c5.xlarge"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "job_name": "rl-stabebaselines-pacman-2021-05-18-00-36-34-642",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz",
#     "module_name": "train_stable_baselines",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_stable_baselines.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"RLSTABLEBASELINES_PRESET":"preset-pacman.py","instance_type":"ml.c5.xlarge","num_timesteps":10000.0}
# SM_USER_ENTRY_POINT=train_stable_baselines.py
# SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=train_stable_baselines
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"RLSTABLEBASELINES_PRESET":"preset-pacman.py","instance_type":"ml.c5.xlarge","num_timesteps":10000.0},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","job_name":"rl-stabebaselines-pacman-2021-05-18-00-36-34-642","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz","module_name":"train_stable_baselines","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train_stable_baselines.py"}
# SM_USER_ARGS=["--RLSTABLEBASELINES_PRESET","preset-pacman.py","--instance_type","ml.c5.xlarge","--num_timesteps","10000.0"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_NUM_TIMESTEPS=10000.0
# SM_HP_RLSTABLEBASELINES_PRESET=preset-pacman.py
# SM_HP_INSTANCE_TYPE=ml.c5.xlarge
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/opt/baselines:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python train_stable_baselines.py --RLSTABLEBASELINES_PRESET preset-pacman.py --instance_type ml.c5.xlarge --num_timesteps 10000.0
#
#
# Launching train script with MPI: preset-pacman.py and arguments: ['--num_timesteps', '10000.0']
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2'] current host: algo-2
# Inside Worker
# Worker node algo-2 is waiting for MPI to start training process
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-05-18 00:41:04,133 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-05-18 00:41:04,138 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-18 00:41:04,379 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-18 00:41:04,390 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_estimator": "RLEstimator"
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "num_timesteps": 10000.0,
#         "RLSTABLEBASELINES_PRESET": "preset-pacman.py",
#         "instance_type": "ml.c5.xlarge"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "job_name": "rl-stabebaselines-pacman-2021-05-18-00-36-34-642",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz",
#     "module_name": "train_stable_baselines",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_stable_baselines.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"RLSTABLEBASELINES_PRESET":"preset-pacman.py","instance_type":"ml.c5.xlarge","num_timesteps":10000.0}
# SM_USER_ENTRY_POINT=train_stable_baselines.py
# SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_stable_baselines
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"RLSTABLEBASELINES_PRESET":"preset-pacman.py","instance_type":"ml.c5.xlarge","num_timesteps":10000.0},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","job_name":"rl-stabebaselines-pacman-2021-05-18-00-36-34-642","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz","module_name":"train_stable_baselines","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train_stable_baselines.py"}
# SM_USER_ARGS=["--RLSTABLEBASELINES_PRESET","preset-pacman.py","--instance_type","ml.c5.xlarge","--num_timesteps","10000.0"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_NUM_TIMESTEPS=10000.0
# SM_HP_RLSTABLEBASELINES_PRESET=preset-pacman.py
# SM_HP_INSTANCE_TYPE=ml.c5.xlarge
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/opt/baselines:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python train_stable_baselines.py --RLSTABLEBASELINES_PRESET preset-pacman.py --instance_type ml.c5.xlarge --num_timesteps 10000.0
#
#
# Launching train script with MPI: preset-pacman.py and arguments: ['--num_timesteps', '10000.0']
# MPI requested with process per hosts: 1
# Hosts: ['algo-1', 'algo-2'] current host: algo-1
# Inside Master
# hosts that aren't SSHable yet: ['algo-1', 'algo-2']
# Testing connection to host algo-1
# Can't connect to host algo-1
# Testing connection to host algo-2
# Can connect to host algo-2
# Host: algo-2 is sshable now.
# hosts that aren't SSHable yet: ['algo-1']
# Testing connection to host algo-1
# Can connect to host algo-1
# Host: algo-1 is sshable now.
# Env Hosts: ['algo-1', 'algo-2'] Hosts: ['algo-1', 'algo-2'] process_per_hosts: 1 num_processes: 2
# network interface name:eth0 ml.c5.xlarge
# MPI Command: mpirun --host algo-1,algo-2 -np 2  --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -x NCCL_SOCKET_IFNAME=eth0 --mca plm_rsh_no_tree_spawn 1 -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=8 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/libchangehostname.so -x SM_HOSTS="["algo-1","algo-2"]" -x SM_NETWORK_INTERFACE_NAME="eth0" -x SM_HPS="{"RLSTABLEBASELINES_PRESET":"preset-pacman.py","instance_type":"ml.c5.xlarge","num_timesteps":10000.0}" -x SM_USER_ENTRY_POINT="train_stable_baselines.py" -x SM_FRAMEWORK_PARAMS="{"sagemaker_estimator":"RLEstimator"}" -x SM_RESOURCE_CONFIG="{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}" -x SM_INPUT_DATA_CONFIG="{}" -x SM_OUTPUT_DATA_DIR="/opt/ml/output/data" -x SM_CHANNELS="[]" -x SM_CURRENT_HOST="algo-1" -x SM_MODULE_NAME="train_stable_baselines" -x SM_LOG_LEVEL="20" -x SM_FRAMEWORK_MODULE="sagemaker_tensorflow_container.training:main" -x SM_INPUT_DIR="/opt/ml/input" -x SM_INPUT_CONFIG_DIR="/opt/ml/input/config" -x SM_OUTPUT_DIR="/opt/ml/output" -x SM_NUM_CPUS="4" -x SM_NUM_GPUS="0" -x SM_MODEL_DIR="/opt/ml/model" -x SM_MODULE_DIR="s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz" -x SM_TRAINING_ENV="{"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"RLSTABLEBASELINES_PRESET":"preset-pacman.py","instance_type":"ml.c5.xlarge","num_timesteps":10000.0},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","job_name":"rl-stabebaselines-pacman-2021-05-18-00-36-34-642","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-596030579944/rl-stabebaselines-pacman-2021-05-18-00-36-34-642/source/sourcedir.tar.gz","module_name":"train_stable_baselines","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train_stable_baselines.py"}" -x SM_USER_ARGS="["--RLSTABLEBASELINES_PRESET","preset-pacman.py","--instance_type","ml.c5.xlarge","--num_timesteps","10000.0"]" -x SM_OUTPUT_INTERMEDIATE_DIR="/opt/ml/output/intermediate" -x SM_HP_NUM_TIMESTEPS="10000.0" -x SM_HP_RLSTABLEBASELINES_PRESET="preset-pacman.py" -x SM_HP_INSTANCE_TYPE="ml.c5.xlarge" /mpi_script.sh
# Running user script:
#
# %s #!/usr/bin/env bash
# touch /mpi_is_running
# /usr/bin/python preset-pacman.py --num_timesteps 10000.0 --RLSTABLEBASELINES_PRESET preset-pacman.py --instance_type ml.c5.xlarge --num_timesteps 10000.0
# EXIT_CODE=$?
# touch /mpi_is_finished
# exit ${EXIT_CODE}
#
# Warning: Permanently added 'algo-2,10.0.206.103' (ECDSA) to the list of known hosts.#015
#  Data for JOB [41132,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: algo-1#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [41132,1] App: 0 Process rank: 0 Bound: N/A
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [41132,1] App: 0 Process rank: 1 Bound: N/A
#
#  =============================================================
# MPI started training process on worker node algo-2
# [1,0]<stderr>:WARNING:tensorflow:
# [1,0]<stderr>:The TensorFlow contrib module will not be included in TensorFlow 2.0.
# [1,0]<stderr>:For more information, please see:
# [1,0]<stderr>:  * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
# [1,0]<stderr>:  * https://github.com/tensorflow/addons
# [1,0]<stderr>:  * https://github.com/tensorflow/io (for I/O related ops)
# [1,0]<stderr>:If you depend on functionality not listed there, please file an issue.
# [1,0]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:
# [1,1]<stderr>:The TensorFlow contrib module will not be included in TensorFlow 2.0.
# [1,1]<stderr>:For more information, please see:
# [1,1]<stderr>:  * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
# [1,1]<stderr>:  * https://github.com/tensorflow/addons
# [1,1]<stderr>:  * https://github.com/tensorflow/io (for I/O related ops)
# [1,1]<stderr>:If you depend on functionality not listed there, please file an issue.
# [1,1]<stderr>:
# [1,0]<stderr>:/usr/local/lib/python3.6/dist-packages/stable_baselines/__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
# [1,0]<stderr>:  "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."
# [1,0]<stdout>:Starting training for half cheetah with PPO1
# [1,0]<stdout>:Launching training script with stable baselines PPO1
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/misc_util.py:26: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# [1,0]<stderr>:
# [1,1]<stdout>:Starting training for half cheetah with PPO1
# [1,1]<stdout>:Launching training script with stable baselines PPO1
# [1,1]<stderr>:/usr/local/lib/python3.6/dist-packages/stable_baselines/__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
# [1,1]<stderr>:  "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/misc_util.py:26: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# [1,1]<stderr>:
# [1,0]<stdout>:Initializing PPO with output_path: /opt/ml/output/intermediate/ and Hyper Params [timesteps_per_actorbatch: 2048,clip_param: 0.2, entcoeff: 0.0, optim_epochs: 10, optim_stepsize: 0.0003, optim_batchsize: 64, gamma: 0.99, lam: 0.95, schedule: linear, verbose: 1, num_timesteps: 10000.0]
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# [1,0]<stderr>:
# [1,1]<stdout>:Initializing PPO with output_path: /opt/ml/output/intermediate/ and Hyper Params [timesteps_per_actorbatch: 2048,clip_param: 0.2, entcoeff: 0.0, optim_epochs: 10, optim_stepsize: 0.0003, optim_batchsize: 64, gamma: 0.99, lam: 0.95, schedule: linear, verbose: 1, num_timesteps: 10000.0]
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# [1,1]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Use keras.layers.flatten instead.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Please use `layer.__call__` method instead.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# [1,0]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Use keras.layers.flatten instead.
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Please use `layer.__call__` method instead.
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# [1,1]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
# [1,0]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/ppo1/pposgd_simple.py:152: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/ppo1/pposgd_simple.py:162: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# [1,1]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/ppo1/pposgd_simple.py:152: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/ppo1/pposgd_simple.py:162: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/common/tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# [1,0]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/ppo1/pposgd_simple.py:190: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# [1,1]<stderr>:
# [1,1]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Use tf.where in 2.0, which has the same broadcast rule as np.where
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/stable_baselines/ppo1/pposgd_simple.py:190: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# [1,0]<stderr>:
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Use tf.where in 2.0, which has the same broadcast rule as np.where
# [1,1]<stdout>:********** Iteration 0 ************
# [1,0]<stdout>:********** Iteration 0 ************
# [1,0]<stdout>:Optimizing...
# [1,0]<stdout>:     pol_surr |    pol_entpen |       vf_loss |            kl |           ent
# [1,1]<stdout>:Optimizing...
# [1,1]<stdout>:     pol_surr |    pol_entpen |       vf_loss |            kl |           ent
# [1,1]<stdout>:      0.00197 |       0.00000 |     101.27057 |       0.00068 |       2.19650
# [1,0]<stdout>:     -0.00010 |       0.00000 |      90.19932 |       0.00068 |       2.19650
# [1,0]<stdout>:     -0.00644 |       0.00000 |      72.54707 |       0.00345 |       2.19388
# [1,1]<stdout>:      0.00179 |       0.00000 |      82.60219 |       0.00345 |       2.19388
# [1,0]<stdout>:     -0.00968 |       0.00000 |      66.11082 |       0.00901 |       2.18859
# [1,1]<stdout>:      0.00147 |       0.00000 |      74.94608 |       0.00902 |       2.18859
# [1,1]<stdout>:      0.00121 |       0.00000 |      72.46683 |       0.01040 |       2.18718
# [1,0]<stdout>:     -0.01047 |       0.00000 |      64.29324 |       0.01039 |       2.18718
# [1,1]<stdout>:      0.00078 |       0.00000 |      71.95741 |       0.01169 |       2.18597
# [1,0]<stdout>:     -0.01008 |       0.00000 |      63.99811 |       0.01169 |       2.18597
# [1,1]<stdout>:      0.00040 |       0.00000 |      71.85979 |       0.01367 |       2.18390
# [1,0]<stdout>:     -0.01074 |       0.00000 |      64.01503 |       0.01367 |       2.18390
# [1,0]<stdout>:     -0.01120 |       0.00000 |      64.04163 |       0.01497 |       2.18264
# [1,1]<stdout>:      0.00024 |       0.00000 |      71.82982 |       0.01498 |       2.18264

# %% [markdown]
# ## 可视化
#
# 强化学习训练通常需要很长时间，因此在运行过程中我们需要通过多种方式来跟踪正在运行的培训工作的进度。在训练期间，训练任务可以将一些中间输出到S3，我们可以根据这些这里中间输出来进行监控或者分析。

# %% [markdown]
# ### 获取训练输出的视频
# 在训练期间，可以将环境的训练视频将输出到S3。接下来，我们将获取所有可用的视频，并且在notebook中渲染最后一个。
# 我们可以先暂停上一个cell的执行（因为我们已经向SageMaker提交了整合个训练任务）

# %%
job_name = estimator.latest_training_job.job_name
print("Training job: %s" % job_name)

s3_url = "s3://{}/{}".format(s3_bucket,job_name)

output_tar_key = "{}/output/output.tar.gz".format(job_name)

intermediate_folder_key = "{}/output/intermediate".format(job_name)
output_url = "s3://{}/{}".format(s3_bucket, output_tar_key)
intermediate_url = "s3://{}/{}".format(s3_bucket, intermediate_folder_key)

print("S3 job path: {}".format(s3_url))
print("Output.tar.gz location: {}".format(output_url))
print("Intermediate folder path: {}".format(intermediate_url))
    
tmp_dir = "/tmp/{}".format(job_name)
os.system("mkdir {}".format(tmp_dir))
print("Create local folder {}".format(tmp_dir))
wait_for_s3_object(s3_bucket, intermediate_folder_key, tmp_dir)
# Out:
# Training job: rl-stabebaselines-pacman-2021-05-14-06-51-00-187
# S3 job path: s3://sagemaker-us-west-2-907488872981/rl-stabebaselines-pacman-2021-05-14-06-51-00-187
# Output.tar.gz location: s3://sagemaker-us-west-2-907488872981/rl-stabebaselines-pacman-2021-05-14-06-51-00-187/output/output.tar.gz
# Intermediate folder path: s3://sagemaker-us-west-2-907488872981/rl-stabebaselines-pacman-2021-05-14-06-51-00-187/output/intermediate
# Create local folder /tmp/rl-stabebaselines-pacman-2021-05-14-06-51-00-187
# Waiting for s3://sagemaker-us-west-2-907488872981/rl-stabebaselines-pacman-2021-05-14-06-51-00-187/output/intermediate...
# Downloading rl-stabebaselines-pacman-2021-05-14-06-51-00-187/output/intermediate/0.monitor.csv
# Downloading rl-stabebaselines-pacman-2021-05-14-06-51-00-187/output/intermediate/rl_out.meta.json
# Downloading rl-stabebaselines-pacman-2021-05-14-06-51-00-187/output/intermediate/rl_out.mp4
# ['/tmp/rl-stabebaselines-pacman-2021-05-14-06-51-00-187/0.monitor.csv',
#  '/tmp/rl-stabebaselines-pacman-2021-05-14-06-51-00-187/rl_out.meta.json',
#  '/tmp/rl-stabebaselines-pacman-2021-05-14-06-51-00-187/rl_out.mp4']

# %% [markdown]
# ### RL 视频输出

# %%
import io
import base64
video = io.open("{}/rl_out.mp4".format(tmp_dir), 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ### Stabel baselines 参数调整(可选)
#
# 可以调整Stabel baselines 的参数使用更多的机器和step来获得更好的效果:
# * `train_instance_count`: 10
# * `train_instance_type`: ml.c5.xlarge
# * `num_timesteps`: 1e7
#
# 使用上述设置训练模型花费了40分钟。您可以使用更少的实例和更长的培训时间来获得类似的输出。

# %%
import io
import base64
video = io.open("{}/rl_out.mp4", 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
